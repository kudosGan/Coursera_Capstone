# %% [markdown]
# # The Battle of the Neighborhoods- Week1 Part 1

# %% [markdown]
# ### Description of the Problem and Background

# %% [markdown]
# #### Scenario

# %% [markdown]
# Canada stand’s King when it comes to produce Tech Talents. The new 2018 Studies show the top 10 talent markets Ottawa and Waterloo is in Top 5. The Survey Noted major Tech Firms had invested in Toronto because of Location and Attributes. Technology sector needs to flourish, especially when it comes to high concentration of Tech Employment. In Toronto, alone 82,100 new tech jobs created over the period. Further the Tri-cities Kitchener, Cambridge and Waterloo leads the way as the number one location to start a tech Business, mainly because of the University fresh talents. In addition, top ranked in producing high Tech students every Year. Moreover, Toronto leads as the Mecca for the Tech Talents.

# %% [markdown]
# ### Business Problems

# %% [markdown]
# Study shows most of these Talents are not employed in Canada because of local Government, which is not influencing the economy. City property Tax and property price is high for new Graduates to own a decent house and social life and to start a family.  Most of the residents receives double the services  for the tax they paid,  and the business receives  half  of the service  for  what  Business pays , the  tax on the Industries are even steeper it because of the provincial Governments that is  bigger roadblock and it load all the tax on to business. Most cities succeed only if business people, who risk their own capital, Time, effort and ready to gamble on their Futures.
# To Retain the talents within the Canada The Federal Government came up with new Program  called Global Talent Stream, Which is ready to help fast growing Canadian tech Companies recruit and retain highly skilled talent from going around the world.

# %% [markdown]
# ### I have chosen City of Markham where I leverage the foursquare location data to solve the imagined business opportunity for the Startup tech companies.  Why choosing the City of Markham

# %% [markdown]
# #### Background on City of Markham.

# %% [markdown]
# City of Markham located within the Greater Toronto Area of South of Ontario and located approximately 30km northeast of Downtown Toronto. Markham changed its status from Town of Markham to City of Markham in July 1 2012. Nearly produces 22% of its Labors force and has over 1000 technology and life science companies. Most high-tech companies like IBM, Honda Canada, Hyundai, AMD, Johnson and Johnson, Avaya, Motorola, Oracle, Toshiba, Huawei, Honeywell, CDI, Toshiba, GE Energy, Informatics, Nexeya  Lenovo and Genesys. This also means that the market is highly competitive.as it is highly developing city cost of doing business is also high. Thus, any new business ventures or expansion needs to be analyze carefully to reduce risk and get back its ROI.  Markham is under construction and developing stage of its own Downtown with more entertainment area, restaurants and Communities   with high raised Condominium, and University.

# %% [markdown]
# ### Interested Audience

# %% [markdown]
# This Case is applicable for the Startup Tech Business interested in exploring, starting or locating the new business in the Markham City considering the Federal Program Global Talent Stream, and employee‘s benefit.

# %% [markdown]
# # The Battle of the Neighborhoods- Week1 Part 2

# %% [markdown]
# ### Data Section

# %% [markdown]
#  1]In this section the Data used to solve the problem  as described  previously
# Use Foursquare and geopy data to map top 10 venues for all Markham neighborhoods and clustered in groups ( as per Course LAB)

# %% [markdown]
# 2]Use foursquare and geopy data to map the location of Go station and Bus terminals, Highway and Airport and Entertainment districts, separately and on top of the above clustered map in order to be able to identify the venues and ammenities

# %% [markdown]
# 3]Addresses from rental locations will be converted to geodata( lat, long) using Geopy-distance and Nominatim.

# %% [markdown]
# 4]Data will be searched in open data sources if available, from real estate sites if open to reading, libraries or other government agencies such as Federal Service, Provincial Service, and Municipal Service, etc

# %% [markdown]
# # Methodology Section

# %% [markdown]
# a] Data Acquistion
# b] Data Cleaning
# c] Data Analysis
# d] Machine Learning
# e] Preiction

# %% [markdown]
# Importing necessary libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %%
# install the google map api client library
# !pip install -U googlemaps
# Out:
# ...
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/3c/3f/25/ce6d7722dba07e5d4a12d27ab38f3d7add65ef43171b02c819
# Successfully built googlemaps
# ...

# %%
# define the city and get its latitude & longitude 
city = 'Markham'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.854336 -79.326782

# %%
ClIENT_ID = 'UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU' # your Foursquare ID
ClIENT_SECRET = 'KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU
# Foursquare_Secret:KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323

# %%
search_query = ''
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU&client_secret=KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323&ll=43.854336,-79.326782&v=20180604&query=&radius=500&limit=30'

# %%
results = requests.get(url).json()
#results
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d34b1cf49b14d0023878dca'},
#  'response': {'venues': [{'id': '539a6c67498e78925a27abd2',
#     'name': 'River Park Condos',
#     'location': {'lat': 43.856744691493226,
#      'lng': -79.32452364642623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.856744691493226,
#        'lng': -79.32452364642623}],
#      'distance': 323,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563734479',
#     'hasPerk': False},
#    {'id': '5808dec138fad30e300b85a1',
#     'name': '18 uptown drive markham',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(20)
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 1   [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 2   [{'id': '4bf58dd8d48988d129951735', 'name': 'T...    False
# 3   [{'id': '4bf58dd8d48988d124951735', 'name': 'A...    False
# 4   [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...    False
# 5   [{'id': '4bf58dd8d48988d100951735', 'name': 'P...    False
# 6   [{'id': '56aa371be4b08b9a8d57356a', 'name': 'O...    False
# 7   [{'id': '56aa371be4b08b9a8d5734ff', 'name': 'M...    False
# 8   [{'id': '4bf58dd8d48988d177941735', 'name': 'D...    False
# 9   [{'id': '4bf58dd8d48988d104941735', 'name': 'M...    False
# 10  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...    False
# 11  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 12  [{'id': '4f04aa0c2fb6e1c99f3db0b8', 'name': 'N...    False
# 13  [{'id': '4bf58dd8d48988d1fe941735', 'name': 'M...    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                        name                                categories  \
# 0         River Park Condos  Residential Building (Apartment / Condo)
# 1   18 uptown drive markham  Residential Building (Apartment / Condo)
# 2     Unionville GO Station                             Train Station
# 3  Victoria Park Automotive                           Automotive Shop
# 4      BMO Bank of Montreal                                      Bank
#
#             address  cc     city country      crossStreet  distance  \
# 0               NaN  CA      NaN  Canada              NaN       323
# 1               NaN  CA      NaN  Canada              NaN       229
# 2  7970 Kennedy Rd.  CA  Markham  Canada        at Hwy. 7      1020
# 3               NaN  CA      NaN  Canada              NaN       122
# 4  3993 Highway 7 E  CA  Markham  Canada  at Village Pkwy       479
#
#                                     formattedAddress  \
# 0                                           [Canada]
# ...

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                                  name  \
# 0                                   River Park Condos
# 1                             18 uptown drive markham
# 2                               Unionville GO Station
# 3                            Victoria Park Automotive
# 4                                BMO Bank of Montreal
# 5                                               petco
# 6                              Markham Rotary Ribfest
# 7                                    Markville Clinic
# 8                                       Pearle Vision
# 9                              Form & Function Clinic
# 10                     Unionville High School Library
# 11                              Fitness Centre & Pool
# 12                                     Nice One Nails
# 13                                      Vintage Vibes
# 14                                    TTC Stop #10566
# 15                                      Country Style
# ...

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                                  name  \
# 4                                BMO Bank of Montreal
# 7                                    Markville Clinic
# 8                                       Pearle Vision
# 11                              Fitness Centre & Pool
# 17                                             Cora's
# 18                           Pride Of Canada Carousel
# 19                                         McDonald's
# 20                                 Whole Foods Market
# 21                                          Five Guys
# 22                                  Bed Bath & Beyond
# 23              Beauty Boutique by Shoppers Drug Mart
# 24                           Toronto Marriott Markham
# 25  Hilton Toronto/Markham Suites Conference Centr...
# 26                                 Sansotei Ramen 三草亭
# 27                                      Booster Juice
# 28                                   Patisserie Fleur
# ...

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                                  name categories  \
# 24                           Toronto Marriott Markham      Hotel
# 25  Hilton Toronto/Markham Suites Conference Centr...      Hotel
#
#                      address        lat        lng postalCode state
# 24  170 Enterprise Boulevard  43.849840 -79.324002    L6G 0E6    ON
# 25        8500 Warden Avenue  43.854313 -79.335212    L6G 1A5    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                                  name categories  \
# 24                           Toronto Marriott Markham      Hotel
# 25  Hilton Toronto/Markham Suites Conference Centr...      Hotel
#
#                      address        lat        lng postalCode state
# 24  170 Enterprise Boulevard  43.849840 -79.324002    L6G 0E6    ON
# 25        8500 Warden Avenue  43.854313 -79.335212    L6G 1A5    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'L6G 1A5']
df_hotel
# Out:
#                                                  name categories  \
# 25  Hilton Toronto/Markham Suites Conference Centr...      Hotel
#
#                address        lat        lng postalCode state
# 25  8500 Warden Avenue  43.854313 -79.335212    L6G 1A5    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Restaurant','Breakfast Spot','Fast Food Restaurant','Juice Bar','Dessert Shop','Burger Joint']
Restaurant_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
Restaurant_dataframe
# Out:
#                 name            categories                            address  \
# 17            Cora's        Breakfast Spot                     3760 Highway 7
# 19        McDonald's  Fast Food Restaurant                       3760 Hwy 7 E
# 21         Five Guys          Burger Joint       3987 Highway #7 East, Unit 6
# 27     Booster Juice             Juice Bar                 8505 Warden Avenue
# 28  Patisserie Fleur          Dessert Shop            103-180 Enterprise Blvd
# 29            Mr.Sub            Restaurant  8601 Warden Ave,Unionville Square
#
#           lat        lng postalCode state
# 17  43.856671 -79.332856    L3R 0N2    ON
# 19  43.856748 -79.332191    L3R 0N2    ON
# 21  43.856838 -79.323579    L3R 5M6    ON
# 27  43.856780 -79.333470    L3R 0Y8    ON
# 28  43.849765 -79.323340    L6G 0G4    ON
# 29  43.857678 -79.332127    L3R 0B5    ON

# %%
# search for Parks
search_query = 'communityParks'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU&client_secret=KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323&ll=43.854336,-79.326782&v=20180604&query=communityParks&radius=10000&limit=30'

# %%
park_results = requests.get(url).json()
#results
park_results
# Out:
# {'meta': {'code': 200, 'requestId': '5d34b5e2be70780039384704'},
#  'response': {'venues': [{'id': '5619a365498ec981213559d7',
#     'name': 'Community On The Mount',
#     'location': {'lat': 43.835655212402344,
#      'lng': -79.33172607421875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.835655212402344,
#        'lng': -79.33172607421875}],
#      'distance': 2117,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563735522',
#     'hasPerk': False},
#    {'id': '4fdd6471e4b070b1a599b27a',
#     'name': 'Community on the Mount',
#     'location': {'address': '20 Amber Street',
# ...

# %%
# assign relevant part of JSON to venues
park_venues = park_results['response']['venues']

# tranform venues into a dataframe
park_venues = json_normalize(park_venues)
park_venues.head(5)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d132941735', 'name': 'C...    False
# 2  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...    False
# 4  [{'id': '52e81612bcbc57f1066b7a34', 'name': 'C...    False
#
#                          id            location.address location.cc  \
# 0  5619a365498ec981213559d7                         NaN          CA
# 1  4fdd6471e4b070b1a599b27a             20 Amber Street          CA
# 2  4c77c2f3947ca1cd1a4b4837                 210 Main St          CA
# 3  5955ca9735d3fc2b1fdae7cd             2761 Markham Rd          CA
# 4  4b433b8bf964a52054dd25e3  3990 Major Mackenzie Dr. E          CA
#
#   location.city location.country location.crossStreet  location.distance  \
# 0           NaN           Canada                  NaN               2117
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location

park_venues_columns = ['name', 'categories'] + [col for col in park_venues.columns if col.startswith('location.')]+ ['id']
park_clean_dataframe = park_venues.loc[:,park_venues_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
park_clean_dataframe['categories'] = park_clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
park_clean_dataframe.columns = [column.split('.')[-1] for column in park_clean_dataframe.columns]

park_clean_dataframe.head(50)
# Out:
#                                                  name            categories  \
# 0                              Community On The Mount                Church
# 1                              Community on the Mount                Church
# 2            Crosby Memorial Community Centre & Arena          Skating Rink
# 3                      Community Health & Counselling       Doctor's Office
# 4               Angus Glen Community Centre & Library      Community Center
# 5             Old Unionville Library Community Centre      Community Center
# 6                     Milliken Mills Community Centre      Community Center
# 7                       Community and health services                  None
# 8                       Milliken Mills Community Park        Baseball Field
# 9                             Eden Park Swimming Pool                  Pool
# 10         Toronto Chinese Community Church 多倫多華人基督教會                Church
# ...

# %%
# delete unnecessary columns
park_clean_dataframe1= park_clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
park_clean_dataframe1
# Out:
#                                                  name            categories  \
# 0                              Community On The Mount                Church
# 1                              Community on the Mount                Church
# 2            Crosby Memorial Community Centre & Arena          Skating Rink
# 3                      Community Health & Counselling       Doctor's Office
# 4               Angus Glen Community Centre & Library      Community Center
# 5             Old Unionville Library Community Centre      Community Center
# 6                     Milliken Mills Community Centre      Community Center
# 7                       Community and health services                  None
# 8                       Milliken Mills Community Park        Baseball Field
# 9                             Eden Park Swimming Pool                  Pool
# 10         Toronto Chinese Community Church 多倫多華人基督教會                Church
# ...

# %%
df_park = park_clean_dataframe1.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_park
# Out:
#                                                  name           categories  \
# 3                      Community Health & Counselling      Doctor's Office
# 4               Angus Glen Community Centre & Library     Community Center
# 5             Old Unionville Library Community Centre     Community Center
# 10         Toronto Chinese Community Church 多倫多華人基督教會               Church
# 11                        Centennial Community Centre     Community Center
# 12               Bayview Hill Community Centre & Pool     Community Center
# 15       Markham Christian Community Church  麥城華人基督教會               Church
# 16                  Hagermans Corners Community Homes  Housing Development
# 18  Richmond Hill Christian Community Church 城北華人基督教會               Church
# 19                     Optical Community Aid Services         Home Service
# 20                            L'Amoreaux Park (South)                 Park
# ...

# %%
# search for Parks
search_query = 'School'
radius = 300000

# Define the corresponding URL
url1 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url1
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU&client_secret=KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323&ll=43.854336,-79.326782&v=20180604&query=School&radius=300000&limit=30'

# %%
school_results = requests.get(url1).json()
#results
school_results
# Out:
# {'meta': {'code': 200, 'requestId': '5d34b761f19f44002552a85f'},
#  'response': {'venues': [{'id': '539a6c67498e78925a27abd2',
#     'name': 'River Park Condos',
#     'location': {'lat': 43.856744691493226,
#      'lng': -79.32452364642623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.856744691493226,
#        'lng': -79.32452364642623}],
#      'distance': 323,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563735905',
#     'hasPerk': False},
#    {'id': '51a95492498ef11296366de2',
#     'name': 'Park Inn by Radisson Toronto-Markham',
# ...

# %%
# assign relevant part of JSON to venues
school_venues = school_results['response']['venues']

# tranform venues into a dataframe
school_venues = json_normalize(school_venues)
school_venues.head (10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 5  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 6  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 7  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 8  [{'id': '54541900498ea6ccd0202697', 'name': 'H...    False
# 9  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
#
#                          id             location.address location.cc  \
# 0  539a6c67498e78925a27abd2                          NaN          CA
# 1  51a95492498ef11296366de2           555 Cochrane Drive          CA
# 2  4bb9f1787421a5930d2ec340                          NaN          CA
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
school_clean_columns = ['name', 'categories'] + [col for col in school_venues.columns if col.startswith('location.')]+ ['id']
school_clean_dataframe = school_venues.loc[:,school_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
school_clean_dataframe['categories'] = school_clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
school_clean_dataframe.columns = [column.split('.')[-1] for column in school_clean_dataframe.columns]

school_clean_dataframe.head(2000)
# Out:
#                                                  name  \
# 0                                   River Park Condos
# 1                Park Inn by Radisson Toronto-Markham
# 2                            Victoria Park Automotive
# 3                 Richmond Green Sports Centre & Park
# 4                                       Milliken Park
# 5                                 Angus Glen Dog Park
# 6                         Milne Dam Conservation Park
# 7                                      Mill Pond Park
# 8   Park Lane Beauty & Semi-Permanent Makeup 柏麗光学美...
# 9                   River Park Children's Play Center
# 10               Goldhawk Park Toronto Public Library
# 11                          Victoria Park & Ellesmere
# 12                            L'Amoreaux Park (North)
# 13                        Hwy 401 & Victoria Park Ave
# 14           Park Property Management Inc Head Office
# 15                              Thomson Memorial Park
# ...

# %%
# delete unnecessary columns
clean_dataframe5= clean_dataframe5.drop(['cc',  'country',  'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_dataframe5
# Out:
#                                                  name  \
# 0                              Unionville High School
# 1                          Trillium Montessori School
# 2                        Unionville Montessori School
# 3                                    J Addison School
# 4                      Unionville High School Library
# 5                         Rotman School of Management
# 6                               Toronto French School
# 7                                   SCHOOL Restaurant
# 8                         Schulich School of Business
# 9                 Jackman Avenue Public School Junior
# 10          Hanway Music School in Markham - 海威音乐万锦学院
# 11  Richmond Hill Montessori And Elementary Privat...
# 12                         Queen's School Of Business
# 13                   Unionville Meadows Public School
# 14                           Sun Ling School of Dance
# 15                    Richmond Green Secondary School
# ...

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Markham']
School_dataframe= clean_dataframe5.loc[clean_dataframe5['city'].isin(array)]
School_dataframe
# Out:
#                                          name         categories  \
# 1                  Trillium Montessori School  Elementary School
# 2                Unionville Montessori School             School
# 3                            J Addison School  Elementary School
# 4              Unionville High School Library            Library
# 5   Hanway Music School in Markham - 海威音乐万锦学院       Music School
# 9                 Greensborough Public School             School
# 11                 Markville Secondary School        High School
# 15     St. Brother André Catholic High School        High School
#
#                         address  cc     city country      crossStreet  \
# 1                 4277 14th Ave  CA  Markham  Canada              NaN
# 2              9400 Kennedy Rd.  CA  Markham  Canada              NaN
# 3               2 Valleywood Dr  CA  Markham  Canada              NaN
# 4     201 Town Centre Boulevard  CA  Markham  Canada              NaN
# ...

# %%
# delete unnecessary columns
School_dataframe1= School_dataframe.drop([ 'crossStreet','distance','cc','formattedAddress','distance',\
                                         'neighborhood','labeledLatLngs','id'], axis=1)
                                     
School_dataframe1
# Out:
#                                          name         categories  \
# 1                  Trillium Montessori School  Elementary School
# 2                Unionville Montessori School             School
# 3                            J Addison School  Elementary School
# 4              Unionville High School Library            Library
# 5   Hanway Music School in Markham - 海威音乐万锦学院       Music School
# 9                 Greensborough Public School             School
# 11                 Markville Secondary School        High School
# 15     St. Brother André Catholic High School        High School
#
#                         address     city country        lat        lng  \
# 1                 4277 14th Ave  Markham  Canada  43.841468 -79.313500
# 2              9400 Kennedy Rd.  Markham  Canada  43.880715 -79.315020
# 3               2 Valleywood Dr  Markham  Canada  43.856664 -79.360528
# 4     201 Town Centre Boulevard  Markham  Canada  43.853086 -79.333637
# ...

# %%
array= ['High School','Markham']
School_dataframe2 = School_dataframe1.loc[School_dataframe1['categories'].isin(array)]\
                    [School_dataframe1['city'].isin(array)]
School_dataframe2
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
#                                       name   categories  \
# 11              Markville Secondary School  High School
# 15  St. Brother André Catholic High School  High School
#
#                   address     city country        lat        lng postalCode  \
# 11           1000 Carlton  Markham  Canada  43.877176 -79.288702        NaN
# 15  6160 16th Avenue East  Markham  Canada  43.893859 -79.259087    L3P 3K8
#
#    state
# 11    ON
# 15    ON

# %%
# search for Parks
search_query = 'Tech'
radius = 1000

# Define the corresponding URL
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=UQREUQKVGIBHLFGEYOVZPNV0JPMTKRJEBHJHTHZGQUIL0CTU&client_secret=KXG4WQ0ZJSIFST0P4VOORPECWP54IZUH5LPRH5YTRNKVZ323&ll=43.854336,-79.326782&v=20180604&query=Tech&radius=1000&limit=30'

# %%
results4 = requests.get(url2).json()
#results
results4
# Out:
# {'meta': {'code': 200, 'requestId': '5d33b87823bb8e0038721d20'},
#  'response': {'venues': [{'id': '4cf12db28333224be7a8088e',
#     'name': 'Toronto College of Technology',
#     'location': {'address': '201 Consumers',
#      'lat': 43.857645118846186,
#      'lng': -79.33088062428061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.857645118846186,
#        'lng': -79.33088062428061}],
#      'distance': 493,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['201 Consumers', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ad941735',
#       'name': 'Trade School',
#       'pluralName': 'Trade Schools',
#       'shortName': 'Trade School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/tradeschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563670649',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues3 = results4['response']['venues']

# tranform venues into a dataframe
dataframe6 = json_normalize(venues3)
dataframe6.head(5)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ad941735', 'name': 'T...    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 2  [{'id': '52f2ab2ebcbc57f1066b8b36', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d122951735', 'name': 'E...    False
#
#                          id  \
# 0  4cf12db28333224be7a8088e
# 1  4f335e26121d835b312a73e9
# 2  5acca626b0405649c5b2ca80
# 3  534de210498e6d9d361d74ed
#
#                                     location.address location.cc  \
# 0                                      201 Consumers          CA
# 1  HSBC Tower, Liberty Square,3601 Hwy7 East, Sui...          CA
# 2                    3601 Highway 7 East, Suite 1004          CA
# 3                              250 Royal Crest Court          CA
#
#   location.city location.country  location.distance  \
# 0       Toronto           Canada                493
# 1       Markham           Canada                974
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe6 = dataframe6.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe6['categories'] = clean_dataframe6.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe6.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe6.head(10)
# Out:
#                             name         categories  \
# 0  Toronto College of Technology       Trade School
# 1        SunTel Technologies Inc             Office
# 2        SunTel Technologies Inc        IT Services
# 3               Lorex Technology  Electronics Store
#
#                                              address  cc     city country  \
# 0                                      201 Consumers  CA  Toronto  Canada
# 1  HSBC Tower, Liberty Square,3601 Hwy7 East, Sui...  CA  Markham  Canada
# 2                    3601 Highway 7 East, Suite 1004  CA  Markham  Canada
# 3                              250 Royal Crest Court  CA  Markham  Canada
#
#    crossStreet  distance                                   formattedAddress  \
# 0          NaN       493                [201 Consumers, Toronto ON, Canada]
# 1          NaN       974  [HSBC Tower, Liberty Square,3601 Hwy7 East, Su...
# 2          NaN      1022  [3601 Highway 7 East, Suite 1004, Markham ON L...
# ...

# %%
# delete unnecessary columns
clean_dataframe6= clean_dataframe6.drop(['cc',  'country','crossStreet',  'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe6
# Out:
#                             name         categories  \
# 0  Toronto College of Technology       Trade School
# 1        SunTel Technologies Inc             Office
# 2        SunTel Technologies Inc        IT Services
# 3               Lorex Technology  Electronics Store
#
#                                              address     city        lat  \
# 0                                      201 Consumers  Toronto  43.857645
# 1  HSBC Tower, Liberty Square,3601 Hwy7 East, Sui...  Markham  43.854145
# 2                    3601 Highway 7 East, Suite 1004  Markham  43.854599
# 3                              250 Royal Crest Court  Markham  43.842606
#
#          lng postalCode state
# 0 -79.330881        NaN    ON
# 1 -79.338917    L3R 0M3    ON
# 2 -79.339517    L3R 0M3    ON
# 3 -79.322169    L3R 3S1    ON

# %%
# delete rows with none values
df_Tech = clean_dataframe6.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Tech
# Out:
#                       name         categories  \
# 1  SunTel Technologies Inc             Office
# 2  SunTel Technologies Inc        IT Services
# 3         Lorex Technology  Electronics Store
#
#                                              address     city        lat  \
# 1  HSBC Tower, Liberty Square,3601 Hwy7 East, Sui...  Markham  43.854145
# 2                    3601 Highway 7 East, Suite 1004  Markham  43.854599
# 3                              250 Royal Crest Court  Markham  43.842606
#
#          lng postalCode state
# 1 -79.338917    L3R 0M3    ON
# 2 -79.339517    L3R 0M3    ON
# 3 -79.322169    L3R 3S1    ON

# %%
# search for Parks
search_query = 'shopping'
radius = 1000

# Define the corresponding URL
url3 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-03597582bb4f> in <module>
#       5 # Define the corresponding URL
#       6 url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
# ----> 7 .format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
#       8 url2
#
# NameError: name 'ClIENT_ID' is not defined

# %%
#results

Shopping_results = requests.get(url3).json()

Shopping_results

# %%
# assign relevant part of JSON to venues
Shopping_venues = results4['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(Shopping_venues)
Shopping_dataframe.head(10)

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
Shopping_clean_dataframe = Shopping_dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
Shopping_clean_dataframe['categories'] = Shopping_clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
Shopping_clean_dataframe.columns = [column.split('.')[-1] for column in Shopping_clean_dataframe.columns]

Shopping_clean_dataframe.head(10)

# %%
# delete unnecessary columns
Shopping_clean_dataframe1= clean_dataframe6.drop(['cc',  'country','crossStreet',  'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
Shopping_clean_dataframe1

# %%
# delete rows with none values
df_Shopping = Shopping_clean_dataframe1.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Shopping

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
Tech_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(df_Tech['lat'],df_Tech['lng'], 
                                           df_Tech['name'], df_Tech['categories'],\
                                              df_Tech['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        icon='glass',
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(Tech_map)  
    

Tech_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
Tech_map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, name, categories, address in zip(df_Tech['lat'],df_Tech['lng'], 
                                           df_Tech['name'], df_Tech['categories'],\
                                              df_Tech['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
    location=[lat, lng],
    popup=folium.Popup(max_width=15)) .add_to(Tech_map),
    
for lat, lng, name, categories, address in zip(clean_dataframe4['lat'],clean_dataframe4['lng'], 
                                           clean_dataframe4['name'], clean_dataframe4['categories'],\
                                              clean_dataframe4['address']):
    
    folium.Marker([lat, lng],icon=folium.Icon(color='blue',icon='shopping-cart')
              ).add_to(Tech_map)

for lat, lng, name, categories, address in zip(df_hotels['lat'],df_hotels['lng'], 
                                           df_hotels['name'], df_hotels['categories'],\
                                              df_hotels['address']):
    
    folium.Marker([lat, lng],icon=folium.Icon(color='green',icon='glass')
              ).add_to(Tech_map)

for lat, lng, name, categories, address in zip(School_dataframe1['lat'],School_dataframe1['lng'], 
                                           School_dataframe1['name'], School_dataframe1['categories'],\
                                              School_dataframe1['address']):
    folium.Marker([lat, lng],icon=folium.Icon(icon="graduation-cap", prefix="fa")
              ).add_to(Tech_map)
    

Tech_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rest_map = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, name, categories, address in zip(clean_dataframe3['lat'],clean_dataframe3['lng'], 
                                           clean_dataframe3['name'], clean_dataframe3['categories'],\
                                             clean_dataframe3['address']):
    folium.Marker([lat, lng],icon=folium.Icon(icon="car", prefix="fa")
                                              
              ).add_to(rest_map)
    

rest_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
